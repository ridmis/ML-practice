# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]

# %%
plt.plot(np.power(x,2),'r+-.',np.power(x,3),'g+-.')
plt.title("example")
plt.xlabel("marks")
plt.ylabel("number of student")
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4][2,4,6,8])
